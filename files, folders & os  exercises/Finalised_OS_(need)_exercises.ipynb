# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Files, Folders & OS (Need) Exercises</span></div>

# %% [markdown]
# ## Scenario
# You are a member of an international team analysing environmental pollution. The project involves ten cities: Cairo, Dhaka, Jakarta, Karachi, Manila, Melbourne, Osaka, Shanghai, Singapore, and Tokyo.
#
# Your task is to process and organise data from various environmental measurements. The provided zip file, os-collaboration-exercise-data.zip, contains all relevant data files for the past year.
#
# ## Things to note
#
# **Data Files**: Each data file is named in the format month-date_city.txt (e.g., may-10_singapore.txt).
# **Data Collection**: Data was recorded sporadically; not all days of each month have corresponding data files. The dates of data collection vary across the cities.
# **Exclusion of Files**: Ignore any non-text files, such as those in .pdf, .png, or .jpg formats.

# %% [markdown]
# ## Task 1:
# We like to convert the filename to a more useful numerical format. Specifically, we want to convert month-date-city.txt. (i.e. may-10-singapore.txt) to a mm-dd-city.txt (i.e. 05-10-singapore.txt) format.
#
# Using the following dictionary (or otherwise), write a snippet of Python code to convert 'oct-08_singapore.txt' to 10-08-singapore.txt.

# %%
   
month_dict = {
'jan': '01', 'feb': '02', 'mar': '03',
'apr': '04', 'may': '05', 'jun': '06',
'jul': '07', 'aug': '08', 'sep': '09',
'oct': '10', 'nov': '11', 'dec': '12'
}
old_file_name = 'oct-08_singapore.txt'

# Extracting month, day, and city

#Take the part before "_" and splits it with "-" as separator. 
parts = old_file_name.split('_')[0].split('-')

#month corresponds to part[0]
#day corresponds to parts[1]
#To get city, you take the part after _, and take the first part before "."
#The part after "." corresponds to the file extension. 
month, day, city = parts[0], parts[1], old_file_name.split('_')[1].split('.')[0]

# Converting month abbreviation to numerical format
month_numerical = month_dict.get(month.lower())

# Creating the new filename
new_filename = f'{month_numerical}-{day}-{city}.txt'

print(new_filename)
# Out:
# 10-08-singapore.txt

# %% [markdown]
# ## Task 2
#
# Incorporate your previous code into a function named rename_my_file(old_file_name) that accepts the old filename as the argument and returns the new file name.

# %%
def rename_my_file(old_file_name): 
    month_dict = {
    'jan': '01', 'feb': '02', 'mar': '03',
    'apr': '04', 'may': '05', 'jun': '06',
    'jul': '07', 'aug': '08', 'sep': '09',
    'oct': '10', 'nov': '11', 'dec': '12'
    }
    # Extracting month, day, and city
    try:
        #Take the part before "_" and splits it with "-" as separator. 
        parts = old_file_name.split('_')[0].split('-')

        #month corresponds to part[0]
        #day corresponds to parts[1]
        #To get city, you take the part after _, and take the first part before "."
        #The part after "." corresponds to the file extension. 
        month, day, city = parts[0], parts[1], old_file_name.split('_')[1].split('.')[0]

        # Converting month abbreviation to numerical format
        month_numerical = month_dict[month]

        # Creating the new filename
        new_filename = f'{month_numerical}-{day}-{city}.txt'

        return new_filename
    except:
        return old_file_name

print(rename_my_file('01-11-singapore.txt'))
# Out:
# 01-11-singapore.txt

# %% [markdown]
# ## Task 3
# Use a for loop to apply the function rename_my_file() to the file list below.
#
# ['oct-08_singapore.txt', 'jul-10_cairo.txt', 'may-15_dhaka.txt',
#  'may-13_cairo.txt', 'oct-21_cairo.txt', 'jan-10_singapore.txt',
#  'jun-20_tokyo.txt', 'aug-06_jakarta.txt', 'dec-21_karachi.txt',
#  'jan-01_tokyo.txt']
#
# Print out your progress in the form old-file-name ----> new-file-name

# %%
file_list = ['oct-08_singapore.txt', 'jul-10_cairo.txt', 'may-15_dhaka.txt', 'may-13_cairo.txt', 'oct-21_cairo.txt', 'jan-10_singapore.txt', 'jun-20_tokyo.txt', 'aug-06_jakarta.txt', 'dec-21_karachi.txt', 'jan-01_tokyo.txt']

for old_file in file_list:
    new_file = rename_my_file(old_file)
    print(f"{old_file} ----> {new_file}")
# Out:
# oct-08_singapore.txt ----> 10-08-singapore.txt
# jul-10_cairo.txt ----> 07-10-cairo.txt
# may-15_dhaka.txt ----> 05-15-dhaka.txt
# may-13_cairo.txt ----> 05-13-cairo.txt
# oct-21_cairo.txt ----> 10-21-cairo.txt
# jan-10_singapore.txt ----> 01-10-singapore.txt
# jun-20_tokyo.txt ----> 06-20-tokyo.txt
# aug-06_jakarta.txt ----> 08-06-jakarta.txt
# dec-21_karachi.txt ----> 12-21-karachi.txt
# jan-01_tokyo.txt ----> 01-01-tokyo.txt

# %% [markdown]
# ## Task 4
# With the help of glob, use rename_my_file() to rename all the .txt files in the folder.
#
# Note that you might have to adjust your function rename_my_file() to accommodate the already renamed files.

# %%
import os
import glob

name_list = glob.glob('./**/*.txt', recursive=True)
#print(name_list)
for file in name_list:
    filename = os.path.split(file)[-1]      # Split filename from the rest 
    new_file = rename_my_file(filename)
    name_path = os.path.join(os.path.split(file)[0], new_file)
    os.rename(file, name_path)
    #print(f'renaming {file} to {name_path}')

# %% [markdown]
# ## Task 5
# Use a for loop to create a folder for each city.
# The list of cities is provided below for your convenience.
#
# ['Cairo', 'Dhaka', 'Jakarta', 'Karachi', 'Manila',
#  'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']

# %%
cities = ['Cairo', 'Dhaka', 'Jakarta', 'Karachi', 'Manila', 'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']
for city in cities:
    try:
        path = os.path.join(".", city)
        os.mkdir(path)
    except:
        print(f"File '{city}' already exist")
        
#This is because I have already made the folders when I ran the code earlier.
# Out:
# File 'Cairo' already exist
# File 'Dhaka' already exist
# File 'Jakarta' already exist
# File 'Karachi' already exist
# File 'Manila' already exist
# File 'Melbourne' already exist
# File 'Osaka' already exist
# File 'Shanghai' already exist
# File 'Singapore' already exist
# File 'Tokyo' already exist

# %% [markdown]
# ## Task 6
#
# Use glob to list all the files from Cairo.
# Now use a for loop and shutil.copy() to copy all the files related to Cairo to the corresponding folder you created.

# %% [markdown]
# It worked once, but it threw me a permission error a couple of times. I still don't really know why.

# %%
import os
import glob
import shutil

try:
    cairo_list = glob.glob('./**/*cairo*', recursive=True)
    cairo_file = os.path.join('Cairo')

    for file in cairo_list:
        shutil.copy(file, cairo_file)
except:
    print("The files are already transferred. Please check 'Cairo' folder!")

# This loop iterates through each file path in cairo_list 
# and copies each file to the destination specified by cairo_file using shutil.copy.
# Out:
# The files are already transferred. Please check 'Cairo' folder!

# %% [markdown]
# ## Task 7
#
# Tweak your code to move all the files to the corresponding folders of all the cities.

# %% [markdown]
# Files are now sorted

# %%
cities = ['Cairo', 'Dhaka', 'Jakarta', 'Karachi', 'Manila', 'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']

for city in cities:
    #Replace "cairo" with city
    city_files = glob.glob(f'./**/*{city}*', recursive=True)

    # Set the destination directory for each city
    city_directory = os.path.join(city)

    # Iterate through files for the current city and move them to the corresponding directory
    for file in city_files:
        try:
            shutil.move(file, city_directory)
        except:
            print(f"{file} already exist in {city_directory} folder")
# Out:
# .\Cairo\01-02-cairo.txt already exist in Cairo folder
# .\Cairo\01-03-cairo.txt already exist in Cairo folder
# .\Cairo\01-04-cairo.txt already exist in Cairo folder
# .\Cairo\01-05-cairo.txt already exist in Cairo folder
# .\Cairo\01-07-cairo.txt already exist in Cairo folder
# .\Cairo\01-08-cairo.txt already exist in Cairo folder
# .\Cairo\01-09-cairo.txt already exist in Cairo folder
# .\Cairo\01-11-cairo.txt already exist in Cairo folder
# .\Cairo\01-12-cairo.txt already exist in Cairo folder
# .\Cairo\01-13-cairo.txt already exist in Cairo folder
# .\Cairo\01-15-cairo.txt already exist in Cairo folder
# .\Cairo\01-16-cairo.txt already exist in Cairo folder
# .\Cairo\01-19-cairo.txt already exist in Cairo folder
# .\Cairo\01-20-cairo.txt already exist in Cairo folder
# .\Cairo\01-21-cairo.txt already exist in Cairo folder
# .\Cairo\01-23-cairo.txt already exist in Cairo folder
# .\Cairo\01-27-cairo.txt already exist in Cairo folder
# .\Cairo\01-30-cairo.txt already exist in Cairo folder
# .\Cairo\02-10-cairo.txt already exist in Cairo folder
# .\Cairo\02-17-cairo.txt already exist in Cairo folder
# .\Cairo\02-20-cairo.txt already exist in Cairo folder
# .\Cairo\02-22-cairo.txt already exist in Cairo folder
# .\Cairo\02-25-cairo.txt already exist in Cairo folder
# .\Cairo\02-26-cairo.txt already exist in Cairo folder
# .\Cairo\03-05-cairo.txt already exist in Cairo folder
# .\Cairo\03-06-cairo.txt already exist in Cairo folder
# .\Cairo\03-12-cairo.txt already exist in Cairo folder
# .\Cairo\03-14-cairo.txt already exist in Cairo folder
# .\Cairo\03-19-cairo.txt already exist in Cairo folder
# .\Cairo\03-24-cairo.txt already exist in Cairo folder
# .\Cairo\04-06-cairo.txt already exist in Cairo folder
# .\Cairo\04-07-cairo.txt already exist in Cairo folder
# .\Cairo\04-10-cairo.txt already exist in Cairo folder
# .\Cairo\04-12-cairo.txt already exist in Cairo folder
# .\Cairo\04-13-cairo.txt already exist in Cairo folder
# .\Cairo\04-14-cairo.txt already exist in Cairo folder
# .\Cairo\04-15-cairo.txt already exist in Cairo folder
# .\Cairo\04-17-cairo.txt already exist in Cairo folder
# .\Cairo\04-20-cairo.txt already exist in Cairo folder
# .\Cairo\04-21-cairo.txt already exist in Cairo folder
# .\Cairo\04-22-cairo.txt already exist in Cairo folder
# .\Cairo\04-23-cairo.txt already exist in Cairo folder
# .\Cairo\04-24-cairo.txt already exist in Cairo folder
# .\Cairo\05-01-cairo.txt already exist in Cairo folder
# .\Cairo\05-02-cairo.txt already exist in Cairo folder
# .\Cairo\05-12-cairo.txt already exist in Cairo folder
# .\Cairo\05-17-cairo.txt already exist in Cairo folder
# .\Cairo\05-25-cairo.txt already exist in Cairo folder
# .\Cairo\05-27-cairo.txt already exist in Cairo folder
# .\Cairo\05-29-cairo.txt already exist in Cairo folder
# .\Cairo\05-30-cairo.txt already exist in Cairo folder
# .\Cairo\06-28-cairo.txt already exist in Cairo folder
# .\Cairo\07-04-cairo.txt already exist in Cairo folder
# .\Cairo\07-08-cairo.txt already exist in Cairo folder
# .\Cairo\07-10-cairo.txt already exist in Cairo folder
# .\Cairo\07-13-cairo.txt already exist in Cairo folder
# .\Cairo\07-14-cairo.txt already exist in Cairo folder
# .\Cairo\07-15-cairo.txt already exist in Cairo folder
# .\Cairo\07-16-cairo.txt already exist in Cairo folder
# .\Cairo\07-17-cairo.txt already exist in Cairo folder
# .\Cairo\07-19-cairo.txt already exist in Cairo folder
# .\Cairo\07-24-cairo.txt already exist in Cairo folder
# .\Cairo\07-26-cairo.txt already exist in Cairo folder
# .\Cairo\07-27-cairo.txt already exist in Cairo folder
# .\Cairo\07-29-cairo.txt already exist in Cairo folder
# .\Cairo\07-30-cairo.txt already exist in Cairo folder
# .\Cairo\08-01-cairo.txt already exist in Cairo folder
# .\Cairo\08-03-cairo.txt already exist in Cairo folder
# .\Cairo\08-04-cairo.txt already exist in Cairo folder
# .\Cairo\08-05-cairo.txt already exist in Cairo folder
# .\Cairo\08-07-cairo.txt already exist in Cairo folder
# .\Cairo\08-08-cairo.txt already exist in Cairo folder
# .\Cairo\08-10-cairo.txt already exist in Cairo folder
# .\Cairo\08-12-cairo.txt already exist in Cairo folder
# .\Cairo\08-14-cairo.txt already exist in Cairo folder
# .\Cairo\08-18-cairo.txt already exist in Cairo folder
# .\Cairo\08-19-cairo.txt already exist in Cairo folder
# .\Cairo\08-20-cairo.txt already exist in Cairo folder
# .\Cairo\08-24-cairo.txt already exist in Cairo folder
# .\Cairo\08-25-cairo.txt already exist in Cairo folder
# .\Cairo\08-26-cairo.txt already exist in Cairo folder
# .\Cairo\09-02-cairo.txt already exist in Cairo folder
# .\Cairo\09-04-cairo.txt already exist in Cairo folder
# .\Cairo\09-05-cairo.txt already exist in Cairo folder
# .\Cairo\09-07-cairo.txt already exist in Cairo folder
# .\Cairo\09-08-cairo.txt already exist in Cairo folder
# .\Cairo\09-11-cairo.txt already exist in Cairo folder
# .\Cairo\09-12-cairo.txt already exist in Cairo folder
# .\Cairo\09-13-cairo.txt already exist in Cairo folder
# .\Cairo\09-16-cairo.txt already exist in Cairo folder
# .\Cairo\09-18-cairo.txt already exist in Cairo folder
# .\Cairo\09-20-cairo.txt already exist in Cairo folder
# .\Cairo\09-22-cairo.txt already exist in Cairo folder
# .\Cairo\09-23-cairo.txt already exist in Cairo folder
# .\Cairo\09-24-cairo.txt already exist in Cairo folder
# .\Cairo\09-25-cairo.txt already exist in Cairo folder
# .\Cairo\09-26-cairo.txt already exist in Cairo folder
# .\Cairo\09-28-cairo.txt already exist in Cairo folder
# .\Cairo\10-23-cairo.txt already exist in Cairo folder
# .\Cairo\11-03-cairo.txt already exist in Cairo folder
# .\Cairo\11-04-cairo.txt already exist in Cairo folder
# .\Cairo\11-05-cairo.txt already exist in Cairo folder
# .\Cairo\11-10-cairo.txt already exist in Cairo folder
# .\Cairo\11-14-cairo.txt already exist in Cairo folder
# .\Cairo\11-17-cairo.txt already exist in Cairo folder
# .\Cairo\11-19-cairo.txt already exist in Cairo folder
# .\Cairo\11-21-cairo.txt already exist in Cairo folder
# .\Cairo\11-29-cairo.txt already exist in Cairo folder
# .\Cairo\12-01-cairo.txt already exist in Cairo folder
# .\Cairo\12-03-cairo.txt already exist in Cairo folder
# .\Cairo\12-04-cairo.txt already exist in Cairo folder
# .\Cairo\12-05-cairo.txt already exist in Cairo folder
# .\Cairo\12-07-cairo.txt already exist in Cairo folder
# .\Cairo\12-09-cairo.txt already exist in Cairo folder
# .\Cairo\12-10-cairo.txt already exist in Cairo folder
# .\Cairo\12-13-cairo.txt already exist in Cairo folder
# .\Cairo\12-17-cairo.txt already exist in Cairo folder
# .\Cairo\12-18-cairo.txt already exist in Cairo folder
# .\Cairo\12-19-cairo.txt already exist in Cairo folder
# .\Cairo\12-21-cairo.txt already exist in Cairo folder
# .\Cairo\12-22-cairo.txt already exist in Cairo folder
# .\Cairo\12-23-cairo.txt already exist in Cairo folder
# .\Cairo\12-26-cairo.txt already exist in Cairo folder
# .\Cairo\12-27-cairo.txt already exist in Cairo folder
# .\Cairo\12-29-cairo.txt already exist in Cairo folder
# .\Cairo\apr-02_cairo.jpg already exist in Cairo folder
# .\Cairo\apr-06_cairo.png already exist in Cairo folder
# .\Cairo\apr-07_cairo.png already exist in Cairo folder
# .\Cairo\apr-10_cairo.png already exist in Cairo folder
# .\Cairo\apr-12_cairo.pdf already exist in Cairo folder
# .\Cairo\apr-12_cairo.png already exist in Cairo folder
# .\Cairo\apr-13_cairo.png already exist in Cairo folder
# .\Cairo\apr-14_cairo.jpg already exist in Cairo folder
# .\Cairo\apr-14_cairo.png already exist in Cairo folder
# .\Cairo\apr-15_cairo.jpg already exist in Cairo folder
# .\Cairo\apr-17_cairo.jpg already exist in Cairo folder
# .\Cairo\apr-17_cairo.pdf already exist in Cairo folder
# .\Cairo\apr-17_cairo.png already exist in Cairo folder
# .\Cairo\apr-20_cairo.jpg already exist in Cairo folder
# .\Cairo\apr-21_cairo.pdf already exist in Cairo folder
# .\Cairo\apr-22_cairo.pdf already exist in Cairo folder
# .\Cairo\apr-23_cairo.jpg already exist in Cairo folder
# .\Cairo\apr-24_cairo.jpg already exist in Cairo folder
# .\Cairo\aug-01_cairo.jpg already exist in Cairo folder
# .\Cairo\aug-01_cairo.png already exist in Cairo folder
# .\Cairo\aug-03_cairo.png already exist in Cairo folder
# .\Cairo\aug-04_cairo.jpg already exist in Cairo folder
# .\Cairo\aug-04_cairo.pdf already exist in Cairo folder
# .\Cairo\aug-05_cairo.pdf already exist in Cairo folder
# .\Cairo\aug-07_cairo.png already exist in Cairo folder
# .\Cairo\aug-08_cairo.jpg already exist in Cairo folder
# .\Cairo\aug-10_cairo.png already exist in Cairo folder
# .\Cairo\aug-12_cairo.jpg already exist in Cairo folder
# .\Cairo\aug-14_cairo.jpg already exist in Cairo folder
# .\Cairo\aug-14_cairo.png already exist in Cairo folder
# .\Cairo\aug-18_cairo.jpg already exist in Cairo folder
# .\Cairo\aug-19_cairo.jpg already exist in Cairo folder
# .\Cairo\aug-20_cairo.png already exist in Cairo folder
# .\Cairo\aug-24_cairo.pdf already exist in Cairo folder
# .\Cairo\aug-25_cairo.png already exist in Cairo folder
# .\Cairo\aug-26_cairo.png already exist in Cairo folder
# .\Cairo\dec-01_cairo.jpg already exist in Cairo folder
# .\Cairo\dec-03_cairo.jpg already exist in Cairo folder
# .\Cairo\dec-03_cairo.png already exist in Cairo folder
# .\Cairo\dec-04_cairo.jpg already exist in Cairo folder
# .\Cairo\dec-04_cairo.pdf already exist in Cairo folder
# .\Cairo\dec-04_cairo.png already exist in Cairo folder
# .\Cairo\dec-05_cairo.png already exist in Cairo folder
# .\Cairo\dec-07_cairo.jpg already exist in Cairo folder
# .\Cairo\dec-09_cairo.png already exist in Cairo folder
# .\Cairo\dec-10_cairo.jpg already exist in Cairo folder
# .\Cairo\dec-10_cairo.pdf already exist in Cairo folder
# .\Cairo\dec-13_cairo.pdf already exist in Cairo folder
# .\Cairo\dec-17_cairo.png already exist in Cairo folder
# .\Cairo\dec-18_cairo.jpg already exist in Cairo folder
# .\Cairo\dec-19_cairo.pdf already exist in Cairo folder
# .\Cairo\dec-21_cairo.png already exist in Cairo folder
# .\Cairo\dec-22_cairo.jpg already exist in Cairo folder
# .\Cairo\dec-23_cairo.pdf already exist in Cairo folder
# .\Cairo\dec-26_cairo.pdf already exist in Cairo folder
# .\Cairo\dec-27_cairo.png already exist in Cairo folder
# .\Cairo\dec-29_cairo.jpg already exist in Cairo folder
# .\Cairo\dec-29_cairo.png already exist in Cairo folder
# .\Cairo\feb-10_cairo.jpg already exist in Cairo folder
# .\Cairo\feb-10_cairo.pdf already exist in Cairo folder
# .\Cairo\feb-17_cairo.jpg already exist in Cairo folder
# .\Cairo\feb-20_cairo.png already exist in Cairo folder
# .\Cairo\feb-22_cairo.pdf already exist in Cairo folder
# .\Cairo\feb-22_cairo.png already exist in Cairo folder
# .\Cairo\feb-25_cairo.jpg already exist in Cairo folder
# .\Cairo\feb-25_cairo.pdf already exist in Cairo folder
# .\Cairo\feb-26_cairo.png already exist in Cairo folder
# .\Cairo\jan-02_cairo.pdf already exist in Cairo folder
# .\Cairo\jan-03_cairo.pdf already exist in Cairo folder
# .\Cairo\jan-04_cairo.jpg already exist in Cairo folder
# .\Cairo\jan-05_cairo.jpg already exist in Cairo folder
# .\Cairo\jan-07_cairo.jpg already exist in Cairo folder
# .\Cairo\jan-08_cairo.png already exist in Cairo folder
# .\Cairo\jan-09_cairo.jpg already exist in Cairo folder
# .\Cairo\jan-11_cairo.png already exist in Cairo folder
# .\Cairo\jan-12_cairo.pdf already exist in Cairo folder
# .\Cairo\jan-13_cairo.png already exist in Cairo folder
# .\Cairo\jan-15_cairo.jpg already exist in Cairo folder
# .\Cairo\jan-15_cairo.png already exist in Cairo folder
# .\Cairo\jan-16_cairo.png already exist in Cairo folder
# .\Cairo\jan-19_cairo.pdf already exist in Cairo folder
# .\Cairo\jan-20_cairo.pdf already exist in Cairo folder
# .\Cairo\jan-21_cairo.jpg already exist in Cairo folder
# .\Cairo\jan-23_cairo.png already exist in Cairo folder
# .\Cairo\jan-27_cairo.jpg already exist in Cairo folder
# .\Cairo\jan-30_cairo.pdf already exist in Cairo folder
# .\Cairo\jul-04_cairo.jpg already exist in Cairo folder
# .\Cairo\jul-08_cairo.png already exist in Cairo folder
# .\Cairo\jul-10_cairo.png already exist in Cairo folder
# .\Cairo\jul-13_cairo.png already exist in Cairo folder
# .\Cairo\jul-14_cairo.jpg already exist in Cairo folder
# .\Cairo\jul-15_cairo.pdf already exist in Cairo folder
# .\Cairo\jul-16_cairo.png already exist in Cairo folder
# .\Cairo\jul-17_cairo.pdf already exist in Cairo folder
# .\Cairo\jul-19_cairo.jpg already exist in Cairo folder
# .\Cairo\jul-24_cairo.pdf already exist in Cairo folder
# .\Cairo\jul-26_cairo.png already exist in Cairo folder
# .\Cairo\jul-27_cairo.png already exist in Cairo folder
# .\Cairo\jul-29_cairo.jpg already exist in Cairo folder
# .\Cairo\jul-30_cairo.png already exist in Cairo folder
# .\Cairo\jun-28_cairo.pdf already exist in Cairo folder
# .\Cairo\mar-05_cairo.pdf already exist in Cairo folder
# .\Cairo\mar-05_cairo.png already exist in Cairo folder
# .\Cairo\mar-06_cairo.pdf already exist in Cairo folder
# .\Cairo\mar-12_cairo.jpg already exist in Cairo folder
# .\Cairo\mar-14_cairo.pdf already exist in Cairo folder
# .\Cairo\mar-19_cairo.jpg already exist in Cairo folder
# .\Cairo\mar-24_cairo.pdf already exist in Cairo folder
# .\Cairo\may-01_cairo.png already exist in Cairo folder
# .\Cairo\may-02_cairo.png already exist in Cairo folder
# .\Cairo\may-12_cairo.png already exist in Cairo folder
# .\Cairo\may-17_cairo.png already exist in Cairo folder
# .\Cairo\may-25_cairo.png already exist in Cairo folder
# .\Cairo\may-27_cairo.pdf already exist in Cairo folder
# .\Cairo\may-29_cairo.pdf already exist in Cairo folder
# .\Cairo\may-30_cairo.jpg already exist in Cairo folder
# .\Cairo\may-30_cairo.png already exist in Cairo folder
# .\Cairo\nov-03_cairo.png already exist in Cairo folder
# .\Cairo\nov-04_cairo.pdf already exist in Cairo folder
# .\Cairo\nov-05_cairo.jpg already exist in Cairo folder
# .\Cairo\nov-05_cairo.png already exist in Cairo folder
# .\Cairo\nov-10_cairo.pdf already exist in Cairo folder
# .\Cairo\nov-14_cairo.pdf already exist in Cairo folder
# .\Cairo\nov-17_cairo.pdf already exist in Cairo folder
# .\Cairo\nov-19_cairo.jpg already exist in Cairo folder
# .\Cairo\nov-21_cairo.pdf already exist in Cairo folder
# .\Cairo\nov-29_cairo.pdf already exist in Cairo folder
# .\Cairo\oct-23_cairo.jpg already exist in Cairo folder
# .\Cairo\sep-02_cairo.png already exist in Cairo folder
# .\Cairo\sep-04_cairo.pdf already exist in Cairo folder
# .\Cairo\sep-05_cairo.pdf already exist in Cairo folder
# .\Cairo\sep-07_cairo.jpg already exist in Cairo folder
# .\Cairo\sep-08_cairo.pdf already exist in Cairo folder
# .\Cairo\sep-11_cairo.png already exist in Cairo folder
# .\Cairo\sep-12_cairo.png already exist in Cairo folder
# .\Cairo\sep-13_cairo.jpg already exist in Cairo folder
# .\Cairo\sep-13_cairo.png already exist in Cairo folder
# .\Cairo\sep-16_cairo.png already exist in Cairo folder
# .\Cairo\sep-18_cairo.pdf already exist in Cairo folder
# .\Cairo\sep-20_cairo.jpg already exist in Cairo folder
# .\Cairo\sep-22_cairo.pdf already exist in Cairo folder
# .\Cairo\sep-23_cairo.pdf already exist in Cairo folder
# .\Cairo\sep-24_cairo.pdf already exist in Cairo folder
# .\Cairo\sep-25_cairo.jpg already exist in Cairo folder
# .\Cairo\sep-25_cairo.pdf already exist in Cairo folder
# .\Cairo\sep-26_cairo.pdf already exist in Cairo folder
# .\Cairo\sep-28_cairo.jpg already exist in Cairo folder
# .\Cairo\sep-28_cairo.pdf already exist in Cairo folder
# .\Cairo\sep-28_cairo.png already exist in Cairo folder
# .\Dhaka\01-15-dhaka.txt already exist in Dhaka folder
# .\Dhaka\02-01-dhaka.txt already exist in Dhaka folder
# .\Dhaka\02-04-dhaka.txt already exist in Dhaka folder
# .\Dhaka\02-08-dhaka.txt already exist in Dhaka folder
# .\Dhaka\02-12-dhaka.txt already exist in Dhaka folder
# .\Dhaka\02-14-dhaka.txt already exist in Dhaka folder
# .\Dhaka\02-20-dhaka.txt already exist in Dhaka folder
# .\Dhaka\02-22-dhaka.txt already exist in Dhaka folder
# .\Dhaka\03-16-dhaka.txt already exist in Dhaka folder
# .\Dhaka\04-19-dhaka.txt already exist in Dhaka folder
# .\Dhaka\04-20-dhaka.txt already exist in Dhaka folder
# .\Dhaka\04-23-dhaka.txt already exist in Dhaka folder
# .\Dhaka\05-01-dhaka.txt already exist in Dhaka folder
# .\Dhaka\05-02-dhaka.txt already exist in Dhaka folder
# .\Dhaka\05-04-dhaka.txt already exist in Dhaka folder
# .\Dhaka\05-05-dhaka.txt already exist in Dhaka folder
# .\Dhaka\05-10-dhaka.txt already exist in Dhaka folder
# .\Dhaka\05-11-dhaka.txt already exist in Dhaka folder
# .\Dhaka\05-14-dhaka.txt already exist in Dhaka folder
# .\Dhaka\05-15-dhaka.txt already exist in Dhaka folder
# .\Dhaka\05-17-dhaka.txt already exist in Dhaka folder
# .\Dhaka\05-21-dhaka.txt already exist in Dhaka folder
# .\Dhaka\05-24-dhaka.txt already exist in Dhaka folder
# .\Dhaka\05-26-dhaka.txt already exist in Dhaka folder
# .\Dhaka\05-27-dhaka.txt already exist in Dhaka folder
# .\Dhaka\05-28-dhaka.txt already exist in Dhaka folder
# .\Dhaka\05-29-dhaka.txt already exist in Dhaka folder
# .\Dhaka\05-30-dhaka.txt already exist in Dhaka folder
# .\Dhaka\06-02-dhaka.txt already exist in Dhaka folder
# .\Dhaka\06-04-dhaka.txt already exist in Dhaka folder
# .\Dhaka\06-05-dhaka.txt already exist in Dhaka folder
# .\Dhaka\06-07-dhaka.txt already exist in Dhaka folder
# .\Dhaka\06-09-dhaka.txt already exist in Dhaka folder
# .\Dhaka\06-11-dhaka.txt already exist in Dhaka folder
# .\Dhaka\06-12-dhaka.txt already exist in Dhaka folder
# .\Dhaka\06-17-dhaka.txt already exist in Dhaka folder
# .\Dhaka\06-18-dhaka.txt already exist in Dhaka folder
# .\Dhaka\06-19-dhaka.txt already exist in Dhaka folder
# .\Dhaka\06-20-dhaka.txt already exist in Dhaka folder
# .\Dhaka\06-21-dhaka.txt already exist in Dhaka folder
# .\Dhaka\06-22-dhaka.txt already exist in Dhaka folder
# .\Dhaka\06-23-dhaka.txt already exist in Dhaka folder
# .\Dhaka\06-24-dhaka.txt already exist in Dhaka folder
# .\Dhaka\06-25-dhaka.txt already exist in Dhaka folder
# .\Dhaka\06-26-dhaka.txt already exist in Dhaka folder
# .\Dhaka\06-27-dhaka.txt already exist in Dhaka folder
# .\Dhaka\06-28-dhaka.txt already exist in Dhaka folder
# .\Dhaka\07-01-dhaka.txt already exist in Dhaka folder
# .\Dhaka\07-02-dhaka.txt already exist in Dhaka folder
# .\Dhaka\07-05-dhaka.txt already exist in Dhaka folder
# .\Dhaka\07-06-dhaka.txt already exist in Dhaka folder
# .\Dhaka\07-08-dhaka.txt already exist in Dhaka folder
# .\Dhaka\07-09-dhaka.txt already exist in Dhaka folder
# .\Dhaka\07-10-dhaka.txt already exist in Dhaka folder
# .\Dhaka\07-11-dhaka.txt already exist in Dhaka folder
# .\Dhaka\07-12-dhaka.txt already exist in Dhaka folder
# .\Dhaka\07-13-dhaka.txt already exist in Dhaka folder
# .\Dhaka\07-15-dhaka.txt already exist in Dhaka folder
# .\Dhaka\07-16-dhaka.txt already exist in Dhaka folder
# .\Dhaka\07-18-dhaka.txt already exist in Dhaka folder
# .\Dhaka\07-23-dhaka.txt already exist in Dhaka folder
# .\Dhaka\07-24-dhaka.txt already exist in Dhaka folder
# .\Dhaka\07-28-dhaka.txt already exist in Dhaka folder
# .\Dhaka\07-30-dhaka.txt already exist in Dhaka folder
# .\Dhaka\08-02-dhaka.txt already exist in Dhaka folder
# .\Dhaka\08-03-dhaka.txt already exist in Dhaka folder
# .\Dhaka\08-05-dhaka.txt already exist in Dhaka folder
# .\Dhaka\08-06-dhaka.txt already exist in Dhaka folder
# .\Dhaka\08-08-dhaka.txt already exist in Dhaka folder
# .\Dhaka\08-09-dhaka.txt already exist in Dhaka folder
# .\Dhaka\08-10-dhaka.txt already exist in Dhaka folder
# .\Dhaka\08-11-dhaka.txt already exist in Dhaka folder
# .\Dhaka\08-14-dhaka.txt already exist in Dhaka folder
# .\Dhaka\08-18-dhaka.txt already exist in Dhaka folder
# .\Dhaka\08-19-dhaka.txt already exist in Dhaka folder
# .\Dhaka\08-20-dhaka.txt already exist in Dhaka folder
# .\Dhaka\08-22-dhaka.txt already exist in Dhaka folder
# .\Dhaka\08-23-dhaka.txt already exist in Dhaka folder
# .\Dhaka\08-25-dhaka.txt already exist in Dhaka folder
# .\Dhaka\08-26-dhaka.txt already exist in Dhaka folder
# .\Dhaka\08-27-dhaka.txt already exist in Dhaka folder
# .\Dhaka\08-30-dhaka.txt already exist in Dhaka folder
# .\Dhaka\09-19-dhaka.txt already exist in Dhaka folder
# .\Dhaka\09-25-dhaka.txt already exist in Dhaka folder
# .\Dhaka\09-29-dhaka.txt already exist in Dhaka folder
# .\Dhaka\10-01-dhaka.txt already exist in Dhaka folder
# .\Dhaka\10-02-dhaka.txt already exist in Dhaka folder
# .\Dhaka\10-04-dhaka.txt already exist in Dhaka folder
# .\Dhaka\10-05-dhaka.txt already exist in Dhaka folder
# .\Dhaka\10-07-dhaka.txt already exist in Dhaka folder
# .\Dhaka\10-09-dhaka.txt already exist in Dhaka folder
# .\Dhaka\10-10-dhaka.txt already exist in Dhaka folder
# .\Dhaka\10-11-dhaka.txt already exist in Dhaka folder
# .\Dhaka\10-12-dhaka.txt already exist in Dhaka folder
# .\Dhaka\10-14-dhaka.txt already exist in Dhaka folder
# .\Dhaka\10-18-dhaka.txt already exist in Dhaka folder
# .\Dhaka\10-21-dhaka.txt already exist in Dhaka folder
# .\Dhaka\10-24-dhaka.txt already exist in Dhaka folder
# .\Dhaka\10-27-dhaka.txt already exist in Dhaka folder
# .\Dhaka\10-29-dhaka.txt already exist in Dhaka folder
# .\Dhaka\10-30-dhaka.txt already exist in Dhaka folder
# .\Dhaka\11-01-dhaka.txt already exist in Dhaka folder
# .\Dhaka\11-02-dhaka.txt already exist in Dhaka folder
# .\Dhaka\11-03-dhaka.txt already exist in Dhaka folder
# .\Dhaka\11-04-dhaka.txt already exist in Dhaka folder
# .\Dhaka\11-06-dhaka.txt already exist in Dhaka folder
# .\Dhaka\11-07-dhaka.txt already exist in Dhaka folder
# .\Dhaka\11-08-dhaka.txt already exist in Dhaka folder
# .\Dhaka\11-11-dhaka.txt already exist in Dhaka folder
# .\Dhaka\11-14-dhaka.txt already exist in Dhaka folder
# .\Dhaka\11-15-dhaka.txt already exist in Dhaka folder
# .\Dhaka\11-16-dhaka.txt already exist in Dhaka folder
# .\Dhaka\11-18-dhaka.txt already exist in Dhaka folder
# .\Dhaka\11-20-dhaka.txt already exist in Dhaka folder
# .\Dhaka\11-22-dhaka.txt already exist in Dhaka folder
# .\Dhaka\11-24-dhaka.txt already exist in Dhaka folder
# .\Dhaka\11-27-dhaka.txt already exist in Dhaka folder
# .\Dhaka\11-28-dhaka.txt already exist in Dhaka folder
# .\Dhaka\11-29-dhaka.txt already exist in Dhaka folder
# .\Dhaka\12-02-dhaka.txt already exist in Dhaka folder
# .\Dhaka\12-03-dhaka.txt already exist in Dhaka folder
# .\Dhaka\12-04-dhaka.txt already exist in Dhaka folder
# .\Dhaka\12-06-dhaka.txt already exist in Dhaka folder
# .\Dhaka\12-09-dhaka.txt already exist in Dhaka folder
# .\Dhaka\12-11-dhaka.txt already exist in Dhaka folder
# .\Dhaka\12-16-dhaka.txt already exist in Dhaka folder
# .\Dhaka\12-17-dhaka.txt already exist in Dhaka folder
# .\Dhaka\12-18-dhaka.txt already exist in Dhaka folder
# .\Dhaka\12-19-dhaka.txt already exist in Dhaka folder
# .\Dhaka\12-20-dhaka.txt already exist in Dhaka folder
# .\Dhaka\12-21-dhaka.txt already exist in Dhaka folder
# .\Dhaka\12-24-dhaka.txt already exist in Dhaka folder
# .\Dhaka\12-27-dhaka.txt already exist in Dhaka folder
# .\Dhaka\12-28-dhaka.txt already exist in Dhaka folder
# .\Dhaka\12-29-dhaka.txt already exist in Dhaka folder
# .\Dhaka\12-30-dhaka.txt already exist in Dhaka folder
# .\Dhaka\apr-19_dhaka.png already exist in Dhaka folder
# .\Dhaka\apr-20_dhaka.png already exist in Dhaka folder
# .\Dhaka\apr-23_dhaka.pdf already exist in Dhaka folder
# .\Dhaka\aug-02_dhaka.jpg already exist in Dhaka folder
# .\Dhaka\aug-03_dhaka.jpg already exist in Dhaka folder
# .\Dhaka\aug-03_dhaka.png already exist in Dhaka folder
# .\Dhaka\aug-05_dhaka.png already exist in Dhaka folder
# .\Dhaka\aug-06_dhaka.pdf already exist in Dhaka folder
# .\Dhaka\aug-08_dhaka.pdf already exist in Dhaka folder
# .\Dhaka\aug-09_dhaka.pdf already exist in Dhaka folder
# .\Dhaka\aug-10_dhaka.jpg already exist in Dhaka folder
# .\Dhaka\aug-10_dhaka.pdf already exist in Dhaka folder
# .\Dhaka\aug-11_dhaka.pdf already exist in Dhaka folder
# .\Dhaka\aug-14_dhaka.pdf already exist in Dhaka folder
# .\Dhaka\aug-18_dhaka.png already exist in Dhaka folder
# .\Dhaka\aug-19_dhaka.jpg already exist in Dhaka folder
# .\Dhaka\aug-20_dhaka.pdf already exist in Dhaka folder
# .\Dhaka\aug-22_dhaka.png already exist in Dhaka folder
# .\Dhaka\aug-23_dhaka.pdf already exist in Dhaka folder
# .\Dhaka\aug-25_dhaka.jpg already exist in Dhaka folder
# .\Dhaka\aug-26_dhaka.jpg already exist in Dhaka folder
# .\Dhaka\aug-27_dhaka.png already exist in Dhaka folder
# .\Dhaka\aug-30_dhaka.pdf already exist in Dhaka folder
# .\Dhaka\dec-02_dhaka.png already exist in Dhaka folder
# .\Dhaka\dec-03_dhaka.pdf already exist in Dhaka folder
# .\Dhaka\dec-04_dhaka.pdf already exist in Dhaka folder
# .\Dhaka\dec-06_dhaka.jpg already exist in Dhaka folder
# .\Dhaka\dec-09_dhaka.jpg already exist in Dhaka folder
# .\Dhaka\dec-11_dhaka.png already exist in Dhaka folder
# .\Dhaka\dec-16_dhaka.pdf already exist in Dhaka folder
# .\Dhaka\dec-16_dhaka.png already exist in Dhaka folder
# .\Dhaka\dec-17_dhaka.pdf already exist in Dhaka folder
# .\Dhaka\dec-18_dhaka.png already exist in Dhaka folder
# .\Dhaka\dec-19_dhaka.png already exist in Dhaka folder
# .\Dhaka\dec-20_dhaka.jpg already exist in Dhaka folder
# .\Dhaka\dec-21_dhaka.pdf already exist in Dhaka folder
# .\Dhaka\dec-21_dhaka.png already exist in Dhaka folder
# .\Dhaka\dec-24_dhaka.pdf already exist in Dhaka folder
# .\Dhaka\dec-27_dhaka.jpg already exist in Dhaka folder
# .\Dhaka\dec-28_dhaka.jpg already exist in Dhaka folder
# .\Dhaka\dec-29_dhaka.png already exist in Dhaka folder
# .\Dhaka\dec-30_dhaka.pdf already exist in Dhaka folder
# .\Dhaka\feb-01_dhaka.png already exist in Dhaka folder
# .\Dhaka\feb-04_dhaka.pdf already exist in Dhaka folder
# .\Dhaka\feb-08_dhaka.png already exist in Dhaka folder
# .\Dhaka\feb-12_dhaka.pdf already exist in Dhaka folder
# .\Dhaka\feb-14_dhaka.png already exist in Dhaka folder
# .\Dhaka\feb-20_dhaka.jpg already exist in Dhaka folder
# .\Dhaka\feb-22_dhaka.jpg already exist in Dhaka folder
# .\Dhaka\jan-15_dhaka.jpg already exist in Dhaka folder
# .\Dhaka\jul-01_dhaka.png already exist in Dhaka folder
# .\Dhaka\jul-02_dhaka.pdf already exist in Dhaka folder
# .\Dhaka\jul-05_dhaka.pdf already exist in Dhaka folder
# .\Dhaka\jul-05_dhaka.png already exist in Dhaka folder
# .\Dhaka\jul-06_dhaka.pdf already exist in Dhaka folder
# .\Dhaka\jul-06_dhaka.png already exist in Dhaka folder
# .\Dhaka\jul-08_dhaka.pdf already exist in Dhaka folder
# .\Dhaka\jul-09_dhaka.jpg already exist in Dhaka folder
# .\Dhaka\jul-10_dhaka.jpg already exist in Dhaka folder
# .\Dhaka\jul-10_dhaka.pdf already exist in Dhaka folder
# .\Dhaka\jul-11_dhaka.pdf already exist in Dhaka folder
# .\Dhaka\jul-12_dhaka.png already exist in Dhaka folder
# .\Dhaka\jul-13_dhaka.pdf already exist in Dhaka folder
# .\Dhaka\jul-15_dhaka.png already exist in Dhaka folder
# .\Dhaka\jul-16_dhaka.jpg already exist in Dhaka folder
# .\Dhaka\jul-16_dhaka.pdf already exist in Dhaka folder
# .\Dhaka\jul-18_dhaka.png already exist in Dhaka folder
# .\Dhaka\jul-23_dhaka.png already exist in Dhaka folder
# .\Dhaka\jul-24_dhaka.jpg already exist in Dhaka folder
# .\Dhaka\jul-28_dhaka.png already exist in Dhaka folder
# .\Dhaka\jul-30_dhaka.pdf already exist in Dhaka folder
# .\Dhaka\jun-02_dhaka.jpg already exist in Dhaka folder
# .\Dhaka\jun-04_dhaka.pdf already exist in Dhaka folder
# .\Dhaka\jun-05_dhaka.pdf already exist in Dhaka folder
# .\Dhaka\jun-07_dhaka.jpg already exist in Dhaka folder
# .\Dhaka\jun-09_dhaka.png already exist in Dhaka folder
# .\Dhaka\jun-11_dhaka.pdf already exist in Dhaka folder
# .\Dhaka\jun-12_dhaka.pdf already exist in Dhaka folder
# .\Dhaka\jun-17_dhaka.pdf already exist in Dhaka folder
# .\Dhaka\jun-17_dhaka.png already exist in Dhaka folder
# .\Dhaka\jun-18_dhaka.pdf already exist in Dhaka folder
# .\Dhaka\jun-18_dhaka.png already exist in Dhaka folder
# .\Dhaka\jun-19_dhaka.pdf already exist in Dhaka folder
# .\Dhaka\jun-19_dhaka.png already exist in Dhaka folder
# .\Dhaka\jun-20_dhaka.png already exist in Dhaka folder
# .\Dhaka\jun-21_dhaka.pdf already exist in Dhaka folder
# .\Dhaka\jun-22_dhaka.pdf already exist in Dhaka folder
# .\Dhaka\jun-23_dhaka.pdf already exist in Dhaka folder
# .\Dhaka\jun-24_dhaka.jpg already exist in Dhaka folder
# .\Dhaka\jun-25_dhaka.pdf already exist in Dhaka folder
# .\Dhaka\jun-26_dhaka.jpg already exist in Dhaka folder
# .\Dhaka\jun-27_dhaka.jpg already exist in Dhaka folder
# .\Dhaka\jun-28_dhaka.png already exist in Dhaka folder
# .\Dhaka\mar-16_dhaka.pdf already exist in Dhaka folder
# .\Dhaka\may-01_dhaka.pdf already exist in Dhaka folder
# .\Dhaka\may-01_dhaka.png already exist in Dhaka folder
# .\Dhaka\may-02_dhaka.jpg already exist in Dhaka folder
# .\Dhaka\may-02_dhaka.png already exist in Dhaka folder
# .\Dhaka\may-04_dhaka.pdf already exist in Dhaka folder
# .\Dhaka\may-05_dhaka.pdf already exist in Dhaka folder
# .\Dhaka\may-10_dhaka.png already exist in Dhaka folder
# .\Dhaka\may-11_dhaka.png already exist in Dhaka folder
# .\Dhaka\may-14_dhaka.pdf already exist in Dhaka folder
# .\Dhaka\may-15_dhaka.png already exist in Dhaka folder
# .\Dhaka\may-17_dhaka.jpg already exist in Dhaka folder
# .\Dhaka\may-17_dhaka.pdf already exist in Dhaka folder
# .\Dhaka\may-21_dhaka.jpg already exist in Dhaka folder
# .\Dhaka\may-24_dhaka.jpg already exist in Dhaka folder
# .\Dhaka\may-26_dhaka.jpg already exist in Dhaka folder
# .\Dhaka\may-26_dhaka.png already exist in Dhaka folder
# .\Dhaka\may-27_dhaka.jpg already exist in Dhaka folder
# .\Dhaka\may-28_dhaka.png already exist in Dhaka folder
# .\Dhaka\may-29_dhaka.jpg already exist in Dhaka folder
# .\Dhaka\may-30_dhaka.png already exist in Dhaka folder
# .\Dhaka\nov-01_dhaka.pdf already exist in Dhaka folder
# .\Dhaka\nov-02_dhaka.jpg already exist in Dhaka folder
# .\Dhaka\nov-02_dhaka.pdf already exist in Dhaka folder
# .\Dhaka\nov-03_dhaka.jpg already exist in Dhaka folder
# .\Dhaka\nov-04_dhaka.jpg already exist in Dhaka folder
# .\Dhaka\nov-06_dhaka.jpg already exist in Dhaka folder
# .\Dhaka\nov-07_dhaka.pdf already exist in Dhaka folder
# .\Dhaka\nov-08_dhaka.pdf already exist in Dhaka folder
# .\Dhaka\nov-11_dhaka.jpg already exist in Dhaka folder
# .\Dhaka\nov-11_dhaka.pdf already exist in Dhaka folder
# .\Dhaka\nov-14_dhaka.jpg already exist in Dhaka folder
# .\Dhaka\nov-15_dhaka.jpg already exist in Dhaka folder
# .\Dhaka\nov-15_dhaka.png already exist in Dhaka folder
# .\Dhaka\nov-16_dhaka.pdf already exist in Dhaka folder
# .\Dhaka\nov-18_dhaka.jpg already exist in Dhaka folder
# .\Dhaka\nov-18_dhaka.pdf already exist in Dhaka folder
# .\Dhaka\nov-20_dhaka.png already exist in Dhaka folder
# .\Dhaka\nov-22_dhaka.jpg already exist in Dhaka folder
# .\Dhaka\nov-24_dhaka.png already exist in Dhaka folder
# .\Dhaka\nov-27_dhaka.jpg already exist in Dhaka folder
# .\Dhaka\nov-28_dhaka.jpg already exist in Dhaka folder
# .\Dhaka\nov-29_dhaka.png already exist in Dhaka folder
# .\Dhaka\oct-01_dhaka.jpg already exist in Dhaka folder
# .\Dhaka\oct-02_dhaka.pdf already exist in Dhaka folder
# .\Dhaka\oct-04_dhaka.pdf already exist in Dhaka folder
# .\Dhaka\oct-04_dhaka.png already exist in Dhaka folder
# .\Dhaka\oct-05_dhaka.jpg already exist in Dhaka folder
# .\Dhaka\oct-07_dhaka.pdf already exist in Dhaka folder
# .\Dhaka\oct-09_dhaka.pdf already exist in Dhaka folder
# .\Dhaka\oct-10_dhaka.pdf already exist in Dhaka folder
# .\Dhaka\oct-10_dhaka.png already exist in Dhaka folder
# .\Dhaka\oct-11_dhaka.png already exist in Dhaka folder
# .\Dhaka\oct-12_dhaka.png already exist in Dhaka folder
# .\Dhaka\oct-14_dhaka.png already exist in Dhaka folder
# .\Dhaka\oct-18_dhaka.jpg already exist in Dhaka folder
# .\Dhaka\oct-18_dhaka.pdf already exist in Dhaka folder
# .\Dhaka\oct-21_dhaka.pdf already exist in Dhaka folder
# .\Dhaka\oct-24_dhaka.png already exist in Dhaka folder
# .\Dhaka\oct-27_dhaka.jpg already exist in Dhaka folder
# .\Dhaka\oct-29_dhaka.pdf already exist in Dhaka folder
# .\Dhaka\oct-29_dhaka.png already exist in Dhaka folder
# .\Dhaka\oct-30_dhaka.jpg already exist in Dhaka folder
# .\Dhaka\oct-30_dhaka.pdf already exist in Dhaka folder
# .\Dhaka\sep-19_dhaka.jpg already exist in Dhaka folder
# .\Dhaka\sep-25_dhaka.png already exist in Dhaka folder
# .\Dhaka\sep-29_dhaka.jpg already exist in Dhaka folder
# .\Jakarta\01-03-jakarta.txt already exist in Jakarta folder
# .\Jakarta\01-04-jakarta.txt already exist in Jakarta folder
# .\Jakarta\01-06-jakarta.txt already exist in Jakarta folder
# .\Jakarta\01-10-jakarta.txt already exist in Jakarta folder
# .\Jakarta\01-12-jakarta.txt already exist in Jakarta folder
# .\Jakarta\01-13-jakarta.txt already exist in Jakarta folder
# .\Jakarta\01-16-jakarta.txt already exist in Jakarta folder
# .\Jakarta\01-19-jakarta.txt already exist in Jakarta folder
# .\Jakarta\01-23-jakarta.txt already exist in Jakarta folder
# .\Jakarta\01-24-jakarta.txt already exist in Jakarta folder
# .\Jakarta\01-26-jakarta.txt already exist in Jakarta folder
# .\Jakarta\01-30-jakarta.txt already exist in Jakarta folder
# .\Jakarta\02-02-jakarta.txt already exist in Jakarta folder
# .\Jakarta\02-04-jakarta.txt already exist in Jakarta folder
# .\Jakarta\02-06-jakarta.txt already exist in Jakarta folder
# .\Jakarta\02-09-jakarta.txt already exist in Jakarta folder
# .\Jakarta\02-10-jakarta.txt already exist in Jakarta folder
# .\Jakarta\02-14-jakarta.txt already exist in Jakarta folder
# .\Jakarta\02-15-jakarta.txt already exist in Jakarta folder
# .\Jakarta\02-20-jakarta.txt already exist in Jakarta folder
# .\Jakarta\02-21-jakarta.txt already exist in Jakarta folder
# .\Jakarta\02-26-jakarta.txt already exist in Jakarta folder
# .\Jakarta\02-27-jakarta.txt already exist in Jakarta folder
# .\Jakarta\03-04-jakarta.txt already exist in Jakarta folder
# .\Jakarta\03-09-jakarta.txt already exist in Jakarta folder
# .\Jakarta\03-11-jakarta.txt already exist in Jakarta folder
# .\Jakarta\03-15-jakarta.txt already exist in Jakarta folder
# .\Jakarta\03-17-jakarta.txt already exist in Jakarta folder
# .\Jakarta\03-18-jakarta.txt already exist in Jakarta folder
# .\Jakarta\03-20-jakarta.txt already exist in Jakarta folder
# .\Jakarta\03-23-jakarta.txt already exist in Jakarta folder
# .\Jakarta\03-25-jakarta.txt already exist in Jakarta folder
# .\Jakarta\03-30-jakarta.txt already exist in Jakarta folder
# .\Jakarta\04-06-jakarta.txt already exist in Jakarta folder
# .\Jakarta\04-13-jakarta.txt already exist in Jakarta folder
# .\Jakarta\04-15-jakarta.txt already exist in Jakarta folder
# .\Jakarta\04-16-jakarta.txt already exist in Jakarta folder
# .\Jakarta\04-20-jakarta.txt already exist in Jakarta folder
# .\Jakarta\04-21-jakarta.txt already exist in Jakarta folder
# .\Jakarta\04-23-jakarta.txt already exist in Jakarta folder
# .\Jakarta\04-24-jakarta.txt already exist in Jakarta folder
# .\Jakarta\04-26-jakarta.txt already exist in Jakarta folder
# .\Jakarta\04-28-jakarta.txt already exist in Jakarta folder
# .\Jakarta\05-01-jakarta.txt already exist in Jakarta folder
# .\Jakarta\05-02-jakarta.txt already exist in Jakarta folder
# .\Jakarta\05-03-jakarta.txt already exist in Jakarta folder
# .\Jakarta\05-05-jakarta.txt already exist in Jakarta folder
# .\Jakarta\05-07-jakarta.txt already exist in Jakarta folder
# .\Jakarta\05-08-jakarta.txt already exist in Jakarta folder
# .\Jakarta\05-13-jakarta.txt already exist in Jakarta folder
# .\Jakarta\05-15-jakarta.txt already exist in Jakarta folder
# .\Jakarta\05-16-jakarta.txt already exist in Jakarta folder
# .\Jakarta\05-17-jakarta.txt already exist in Jakarta folder
# .\Jakarta\05-22-jakarta.txt already exist in Jakarta folder
# .\Jakarta\05-25-jakarta.txt already exist in Jakarta folder
# .\Jakarta\05-28-jakarta.txt already exist in Jakarta folder
# .\Jakarta\05-29-jakarta.txt already exist in Jakarta folder
# .\Jakarta\06-03-jakarta.txt already exist in Jakarta folder
# .\Jakarta\06-04-jakarta.txt already exist in Jakarta folder
# .\Jakarta\06-08-jakarta.txt already exist in Jakarta folder
# .\Jakarta\06-10-jakarta.txt already exist in Jakarta folder
# .\Jakarta\06-15-jakarta.txt already exist in Jakarta folder
# .\Jakarta\06-21-jakarta.txt already exist in Jakarta folder
# .\Jakarta\06-22-jakarta.txt already exist in Jakarta folder
# .\Jakarta\06-25-jakarta.txt already exist in Jakarta folder
# .\Jakarta\06-28-jakarta.txt already exist in Jakarta folder
# .\Jakarta\07-04-jakarta.txt already exist in Jakarta folder
# .\Jakarta\07-09-jakarta.txt already exist in Jakarta folder
# .\Jakarta\07-12-jakarta.txt already exist in Jakarta folder
# .\Jakarta\07-14-jakarta.txt already exist in Jakarta folder
# .\Jakarta\07-16-jakarta.txt already exist in Jakarta folder
# .\Jakarta\07-18-jakarta.txt already exist in Jakarta folder
# .\Jakarta\07-21-jakarta.txt already exist in Jakarta folder
# .\Jakarta\07-23-jakarta.txt already exist in Jakarta folder
# .\Jakarta\07-24-jakarta.txt already exist in Jakarta folder
# .\Jakarta\07-27-jakarta.txt already exist in Jakarta folder
# .\Jakarta\07-28-jakarta.txt already exist in Jakarta folder
# .\Jakarta\07-30-jakarta.txt already exist in Jakarta folder
# .\Jakarta\08-02-jakarta.txt already exist in Jakarta folder
# .\Jakarta\08-05-jakarta.txt already exist in Jakarta folder
# .\Jakarta\08-07-jakarta.txt already exist in Jakarta folder
# .\Jakarta\08-09-jakarta.txt already exist in Jakarta folder
# .\Jakarta\08-11-jakarta.txt already exist in Jakarta folder
# .\Jakarta\08-12-jakarta.txt already exist in Jakarta folder
# .\Jakarta\08-13-jakarta.txt already exist in Jakarta folder
# .\Jakarta\08-17-jakarta.txt already exist in Jakarta folder
# .\Jakarta\08-20-jakarta.txt already exist in Jakarta folder
# .\Jakarta\08-21-jakarta.txt already exist in Jakarta folder
# .\Jakarta\08-22-jakarta.txt already exist in Jakarta folder
# .\Jakarta\08-26-jakarta.txt already exist in Jakarta folder
# .\Jakarta\08-28-jakarta.txt already exist in Jakarta folder
# .\Jakarta\09-03-jakarta.txt already exist in Jakarta folder
# .\Jakarta\09-05-jakarta.txt already exist in Jakarta folder
# .\Jakarta\09-11-jakarta.txt already exist in Jakarta folder
# .\Jakarta\09-12-jakarta.txt already exist in Jakarta folder
# .\Jakarta\09-13-jakarta.txt already exist in Jakarta folder
# .\Jakarta\09-15-jakarta.txt already exist in Jakarta folder
# .\Jakarta\09-16-jakarta.txt already exist in Jakarta folder
# .\Jakarta\09-18-jakarta.txt already exist in Jakarta folder
# .\Jakarta\09-19-jakarta.txt already exist in Jakarta folder
# .\Jakarta\09-20-jakarta.txt already exist in Jakarta folder
# .\Jakarta\09-21-jakarta.txt already exist in Jakarta folder
# .\Jakarta\09-24-jakarta.txt already exist in Jakarta folder
# .\Jakarta\09-25-jakarta.txt already exist in Jakarta folder
# .\Jakarta\09-27-jakarta.txt already exist in Jakarta folder
# .\Jakarta\09-29-jakarta.txt already exist in Jakarta folder
# .\Jakarta\10-03-jakarta.txt already exist in Jakarta folder
# .\Jakarta\10-04-jakarta.txt already exist in Jakarta folder
# .\Jakarta\10-05-jakarta.txt already exist in Jakarta folder
# .\Jakarta\10-06-jakarta.txt already exist in Jakarta folder
# .\Jakarta\10-07-jakarta.txt already exist in Jakarta folder
# .\Jakarta\10-08-jakarta.txt already exist in Jakarta folder
# .\Jakarta\10-09-jakarta.txt already exist in Jakarta folder
# .\Jakarta\10-10-jakarta.txt already exist in Jakarta folder
# .\Jakarta\10-12-jakarta.txt already exist in Jakarta folder
# .\Jakarta\10-13-jakarta.txt already exist in Jakarta folder
# .\Jakarta\10-14-jakarta.txt already exist in Jakarta folder
# .\Jakarta\10-15-jakarta.txt already exist in Jakarta folder
# .\Jakarta\10-16-jakarta.txt already exist in Jakarta folder
# .\Jakarta\10-17-jakarta.txt already exist in Jakarta folder
# .\Jakarta\10-23-jakarta.txt already exist in Jakarta folder
# .\Jakarta\10-24-jakarta.txt already exist in Jakarta folder
# .\Jakarta\10-26-jakarta.txt already exist in Jakarta folder
# .\Jakarta\10-27-jakarta.txt already exist in Jakarta folder
# .\Jakarta\10-29-jakarta.txt already exist in Jakarta folder
# .\Jakarta\11-19-jakarta.txt already exist in Jakarta folder
# .\Jakarta\11-20-jakarta.txt already exist in Jakarta folder
# .\Jakarta\12-03-jakarta.txt already exist in Jakarta folder
# .\Jakarta\12-04-jakarta.txt already exist in Jakarta folder
# .\Jakarta\12-07-jakarta.txt already exist in Jakarta folder
# .\Jakarta\12-09-jakarta.txt already exist in Jakarta folder
# .\Jakarta\12-11-jakarta.txt already exist in Jakarta folder
# .\Jakarta\12-12-jakarta.txt already exist in Jakarta folder
# .\Jakarta\12-15-jakarta.txt already exist in Jakarta folder
# .\Jakarta\12-16-jakarta.txt already exist in Jakarta folder
# .\Jakarta\12-18-jakarta.txt already exist in Jakarta folder
# .\Jakarta\12-20-jakarta.txt already exist in Jakarta folder
# .\Jakarta\12-23-jakarta.txt already exist in Jakarta folder
# .\Jakarta\12-26-jakarta.txt already exist in Jakarta folder
# .\Jakarta\12-27-jakarta.txt already exist in Jakarta folder
# .\Jakarta\12-29-jakarta.txt already exist in Jakarta folder
# .\Jakarta\12-30-jakarta.txt already exist in Jakarta folder
# .\Jakarta\apr-02_jakarta.png already exist in Jakarta folder
# .\Jakarta\apr-06_jakarta.pdf already exist in Jakarta folder
# .\Jakarta\apr-13_jakarta.pdf already exist in Jakarta folder
# .\Jakarta\apr-13_jakarta.png already exist in Jakarta folder
# .\Jakarta\apr-15_jakarta.pdf already exist in Jakarta folder
# .\Jakarta\apr-15_jakarta.png already exist in Jakarta folder
# .\Jakarta\apr-16_jakarta.png already exist in Jakarta folder
# .\Jakarta\apr-20_jakarta.pdf already exist in Jakarta folder
# .\Jakarta\apr-21_jakarta.png already exist in Jakarta folder
# .\Jakarta\apr-23_jakarta.pdf already exist in Jakarta folder
# .\Jakarta\apr-23_jakarta.png already exist in Jakarta folder
# .\Jakarta\apr-24_jakarta.png already exist in Jakarta folder
# .\Jakarta\apr-26_jakarta.jpg already exist in Jakarta folder
# .\Jakarta\apr-26_jakarta.pdf already exist in Jakarta folder
# .\Jakarta\apr-28_jakarta.pdf already exist in Jakarta folder
# .\Jakarta\aug-02_jakarta.jpg already exist in Jakarta folder
# .\Jakarta\aug-05_jakarta.jpg already exist in Jakarta folder
# .\Jakarta\aug-07_jakarta.jpg already exist in Jakarta folder
# .\Jakarta\aug-07_jakarta.png already exist in Jakarta folder
# .\Jakarta\aug-09_jakarta.jpg already exist in Jakarta folder
# .\Jakarta\aug-11_jakarta.jpg already exist in Jakarta folder
# .\Jakarta\aug-12_jakarta.pdf already exist in Jakarta folder
# .\Jakarta\aug-13_jakarta.jpg already exist in Jakarta folder
# .\Jakarta\aug-17_jakarta.png already exist in Jakarta folder
# .\Jakarta\aug-20_jakarta.jpg already exist in Jakarta folder
# .\Jakarta\aug-20_jakarta.png already exist in Jakarta folder
# .\Jakarta\aug-21_jakarta.pdf already exist in Jakarta folder
# .\Jakarta\aug-22_jakarta.pdf already exist in Jakarta folder
# .\Jakarta\aug-26_jakarta.pdf already exist in Jakarta folder
# .\Jakarta\aug-28_jakarta.jpg already exist in Jakarta folder
# .\Jakarta\dec-03_jakarta.png already exist in Jakarta folder
# .\Jakarta\dec-04_jakarta.png already exist in Jakarta folder
# .\Jakarta\dec-07_jakarta.jpg already exist in Jakarta folder
# .\Jakarta\dec-09_jakarta.jpg already exist in Jakarta folder
# .\Jakarta\dec-11_jakarta.jpg already exist in Jakarta folder
# .\Jakarta\dec-12_jakarta.pdf already exist in Jakarta folder
# .\Jakarta\dec-15_jakarta.jpg already exist in Jakarta folder
# .\Jakarta\dec-15_jakarta.png already exist in Jakarta folder
# .\Jakarta\dec-16_jakarta.png already exist in Jakarta folder
# .\Jakarta\dec-18_jakarta.pdf already exist in Jakarta folder
# .\Jakarta\dec-20_jakarta.jpg already exist in Jakarta folder
# .\Jakarta\dec-20_jakarta.pdf already exist in Jakarta folder
# .\Jakarta\dec-23_jakarta.jpg already exist in Jakarta folder
# .\Jakarta\dec-26_jakarta.pdf already exist in Jakarta folder
# .\Jakarta\dec-27_jakarta.png already exist in Jakarta folder
# .\Jakarta\dec-29_jakarta.png already exist in Jakarta folder
# .\Jakarta\dec-30_jakarta.png already exist in Jakarta folder
# .\Jakarta\feb-02_jakarta.png already exist in Jakarta folder
# .\Jakarta\feb-04_jakarta.png already exist in Jakarta folder
# .\Jakarta\feb-06_jakarta.jpg already exist in Jakarta folder
# .\Jakarta\feb-09_jakarta.png already exist in Jakarta folder
# .\Jakarta\feb-10_jakarta.png already exist in Jakarta folder
# .\Jakarta\feb-14_jakarta.png already exist in Jakarta folder
# .\Jakarta\feb-15_jakarta.jpg already exist in Jakarta folder
# .\Jakarta\feb-20_jakarta.pdf already exist in Jakarta folder
# .\Jakarta\feb-21_jakarta.jpg already exist in Jakarta folder
# .\Jakarta\feb-26_jakarta.png already exist in Jakarta folder
# .\Jakarta\feb-27_jakarta.png already exist in Jakarta folder
# .\Jakarta\jan-03_jakarta.jpg already exist in Jakarta folder
# .\Jakarta\jan-04_jakarta.jpg already exist in Jakarta folder
# .\Jakarta\jan-06_jakarta.jpg already exist in Jakarta folder
# .\Jakarta\jan-06_jakarta.pdf already exist in Jakarta folder
# .\Jakarta\jan-06_jakarta.png already exist in Jakarta folder
# .\Jakarta\jan-10_jakarta.png already exist in Jakarta folder
# .\Jakarta\jan-12_jakarta.jpg already exist in Jakarta folder
# .\Jakarta\jan-12_jakarta.pdf already exist in Jakarta folder
# .\Jakarta\jan-13_jakarta.jpg already exist in Jakarta folder
# .\Jakarta\jan-16_jakarta.jpg already exist in Jakarta folder
# .\Jakarta\jan-16_jakarta.pdf already exist in Jakarta folder
# .\Jakarta\jan-16_jakarta.png already exist in Jakarta folder
# .\Jakarta\jan-19_jakarta.jpg already exist in Jakarta folder
# .\Jakarta\jan-23_jakarta.jpg already exist in Jakarta folder
# .\Jakarta\jan-24_jakarta.pdf already exist in Jakarta folder
# .\Jakarta\jan-26_jakarta.png already exist in Jakarta folder
# .\Jakarta\jan-30_jakarta.jpg already exist in Jakarta folder
# .\Jakarta\jan-30_jakarta.png already exist in Jakarta folder
# .\Jakarta\jul-04_jakarta.png already exist in Jakarta folder
# .\Jakarta\jul-09_jakarta.pdf already exist in Jakarta folder
# .\Jakarta\jul-12_jakarta.jpg already exist in Jakarta folder
# .\Jakarta\jul-12_jakarta.png already exist in Jakarta folder
# .\Jakarta\jul-14_jakarta.png already exist in Jakarta folder
# .\Jakarta\jul-16_jakarta.png already exist in Jakarta folder
# .\Jakarta\jul-18_jakarta.pdf already exist in Jakarta folder
# .\Jakarta\jul-21_jakarta.jpg already exist in Jakarta folder
# .\Jakarta\jul-23_jakarta.jpg already exist in Jakarta folder
# .\Jakarta\jul-24_jakarta.pdf already exist in Jakarta folder
# .\Jakarta\jul-24_jakarta.png already exist in Jakarta folder
# .\Jakarta\jul-27_jakarta.pdf already exist in Jakarta folder
# .\Jakarta\jul-28_jakarta.pdf already exist in Jakarta folder
# .\Jakarta\jul-30_jakarta.pdf already exist in Jakarta folder
# .\Jakarta\jun-03_jakarta.pdf already exist in Jakarta folder
# .\Jakarta\jun-04_jakarta.jpg already exist in Jakarta folder
# .\Jakarta\jun-08_jakarta.png already exist in Jakarta folder
# .\Jakarta\jun-10_jakarta.pdf already exist in Jakarta folder
# .\Jakarta\jun-15_jakarta.pdf already exist in Jakarta folder
# .\Jakarta\jun-15_jakarta.png already exist in Jakarta folder
# .\Jakarta\jun-21_jakarta.pdf already exist in Jakarta folder
# .\Jakarta\jun-22_jakarta.jpg already exist in Jakarta folder
# .\Jakarta\jun-25_jakarta.png already exist in Jakarta folder
# .\Jakarta\jun-28_jakarta.jpg already exist in Jakarta folder
# .\Jakarta\jun-28_jakarta.png already exist in Jakarta folder
# .\Jakarta\mar-04_jakarta.pdf already exist in Jakarta folder
# .\Jakarta\mar-09_jakarta.pdf already exist in Jakarta folder
# .\Jakarta\mar-11_jakarta.jpg already exist in Jakarta folder
# .\Jakarta\mar-15_jakarta.jpg already exist in Jakarta folder
# .\Jakarta\mar-17_jakarta.jpg already exist in Jakarta folder
# .\Jakarta\mar-18_jakarta.png already exist in Jakarta folder
# .\Jakarta\mar-20_jakarta.pdf already exist in Jakarta folder
# .\Jakarta\mar-23_jakarta.jpg already exist in Jakarta folder
# .\Jakarta\mar-23_jakarta.pdf already exist in Jakarta folder
# .\Jakarta\mar-25_jakarta.png already exist in Jakarta folder
# .\Jakarta\mar-30_jakarta.jpg already exist in Jakarta folder
# .\Jakarta\may-01_jakarta.jpg already exist in Jakarta folder
# .\Jakarta\may-02_jakarta.jpg already exist in Jakarta folder
# .\Jakarta\may-03_jakarta.jpg already exist in Jakarta folder
# .\Jakarta\may-05_jakarta.jpg already exist in Jakarta folder
# .\Jakarta\may-07_jakarta.jpg already exist in Jakarta folder
# .\Jakarta\may-08_jakarta.jpg already exist in Jakarta folder
# .\Jakarta\may-08_jakarta.png already exist in Jakarta folder
# .\Jakarta\may-13_jakarta.jpg already exist in Jakarta folder
# .\Jakarta\may-13_jakarta.pdf already exist in Jakarta folder
# .\Jakarta\may-13_jakarta.png already exist in Jakarta folder
# .\Jakarta\may-15_jakarta.jpg already exist in Jakarta folder
# .\Jakarta\may-16_jakarta.png already exist in Jakarta folder
# .\Jakarta\may-17_jakarta.pdf already exist in Jakarta folder
# .\Jakarta\may-17_jakarta.png already exist in Jakarta folder
# .\Jakarta\may-22_jakarta.pdf already exist in Jakarta folder
# .\Jakarta\may-25_jakarta.pdf already exist in Jakarta folder
# .\Jakarta\may-28_jakarta.pdf already exist in Jakarta folder
# .\Jakarta\may-29_jakarta.png already exist in Jakarta folder
# .\Jakarta\nov-19_jakarta.jpg already exist in Jakarta folder
# .\Jakarta\nov-20_jakarta.pdf already exist in Jakarta folder
# .\Jakarta\oct-03_jakarta.pdf already exist in Jakarta folder
# .\Jakarta\oct-04_jakarta.pdf already exist in Jakarta folder
# .\Jakarta\oct-05_jakarta.jpg already exist in Jakarta folder
# .\Jakarta\oct-06_jakarta.jpg already exist in Jakarta folder
# .\Jakarta\oct-07_jakarta.png already exist in Jakarta folder
# ...
# .\Tokyo\03-05-tokyo.txt already exist in Tokyo folder
# .\Tokyo\03-09-tokyo.txt already exist in Tokyo folder
# .\Tokyo\03-14-tokyo.txt already exist in Tokyo folder
# .\Tokyo\03-15-tokyo.txt already exist in Tokyo folder
# .\Tokyo\03-16-tokyo.txt already exist in Tokyo folder
# .\Tokyo\03-18-tokyo.txt already exist in Tokyo folder
# .\Tokyo\03-26-tokyo.txt already exist in Tokyo folder
# .\Tokyo\03-27-tokyo.txt already exist in Tokyo folder
# .\Tokyo\04-03-tokyo.txt already exist in Tokyo folder
# .\Tokyo\04-07-tokyo.txt already exist in Tokyo folder
# .\Tokyo\04-10-tokyo.txt already exist in Tokyo folder
# .\Tokyo\04-11-tokyo.txt already exist in Tokyo folder
# .\Tokyo\04-12-tokyo.txt already exist in Tokyo folder
# .\Tokyo\04-15-tokyo.txt already exist in Tokyo folder
# .\Tokyo\04-17-tokyo.txt already exist in Tokyo folder
# .\Tokyo\04-18-tokyo.txt already exist in Tokyo folder
# .\Tokyo\04-20-tokyo.txt already exist in Tokyo folder
# .\Tokyo\04-21-tokyo.txt already exist in Tokyo folder
# .\Tokyo\04-23-tokyo.txt already exist in Tokyo folder
# .\Tokyo\04-24-tokyo.txt already exist in Tokyo folder
# .\Tokyo\04-27-tokyo.txt already exist in Tokyo folder
# .\Tokyo\04-28-tokyo.txt already exist in Tokyo folder
# .\Tokyo\04-29-tokyo.txt already exist in Tokyo folder
# .\Tokyo\05-01-tokyo.txt already exist in Tokyo folder
# .\Tokyo\05-02-tokyo.txt already exist in Tokyo folder
# .\Tokyo\05-03-tokyo.txt already exist in Tokyo folder
# .\Tokyo\05-05-tokyo.txt already exist in Tokyo folder
# .\Tokyo\05-08-tokyo.txt already exist in Tokyo folder
# .\Tokyo\05-15-tokyo.txt already exist in Tokyo folder
# .\Tokyo\05-16-tokyo.txt already exist in Tokyo folder
# .\Tokyo\05-17-tokyo.txt already exist in Tokyo folder
# .\Tokyo\05-23-tokyo.txt already exist in Tokyo folder
# .\Tokyo\05-28-tokyo.txt already exist in Tokyo folder
# .\Tokyo\05-30-tokyo.txt already exist in Tokyo folder
# .\Tokyo\06-05-tokyo.txt already exist in Tokyo folder
# .\Tokyo\06-07-tokyo.txt already exist in Tokyo folder
# .\Tokyo\06-08-tokyo.txt already exist in Tokyo folder
# .\Tokyo\06-11-tokyo.txt already exist in Tokyo folder
# .\Tokyo\06-12-tokyo.txt already exist in Tokyo folder
# .\Tokyo\06-14-tokyo.txt already exist in Tokyo folder
# .\Tokyo\06-17-tokyo.txt already exist in Tokyo folder
# .\Tokyo\06-18-tokyo.txt already exist in Tokyo folder
# .\Tokyo\06-20-tokyo.txt already exist in Tokyo folder
# .\Tokyo\06-22-tokyo.txt already exist in Tokyo folder
# .\Tokyo\06-23-tokyo.txt already exist in Tokyo folder
# .\Tokyo\06-25-tokyo.txt already exist in Tokyo folder
# .\Tokyo\06-28-tokyo.txt already exist in Tokyo folder
# .\Tokyo\06-29-tokyo.txt already exist in Tokyo folder
# .\Tokyo\07-02-tokyo.txt already exist in Tokyo folder
# .\Tokyo\07-04-tokyo.txt already exist in Tokyo folder
# .\Tokyo\07-05-tokyo.txt already exist in Tokyo folder
# .\Tokyo\07-06-tokyo.txt already exist in Tokyo folder
# .\Tokyo\07-10-tokyo.txt already exist in Tokyo folder
# .\Tokyo\07-11-tokyo.txt already exist in Tokyo folder
# .\Tokyo\07-12-tokyo.txt already exist in Tokyo folder
# .\Tokyo\07-13-tokyo.txt already exist in Tokyo folder
# .\Tokyo\07-15-tokyo.txt already exist in Tokyo folder
# .\Tokyo\07-19-tokyo.txt already exist in Tokyo folder
# .\Tokyo\07-20-tokyo.txt already exist in Tokyo folder
# .\Tokyo\07-26-tokyo.txt already exist in Tokyo folder
# .\Tokyo\07-27-tokyo.txt already exist in Tokyo folder
# .\Tokyo\07-28-tokyo.txt already exist in Tokyo folder
# .\Tokyo\07-29-tokyo.txt already exist in Tokyo folder
# .\Tokyo\08-05-tokyo.txt already exist in Tokyo folder
# .\Tokyo\08-12-tokyo.txt already exist in Tokyo folder
# .\Tokyo\08-14-tokyo.txt already exist in Tokyo folder
# .\Tokyo\08-20-tokyo.txt already exist in Tokyo folder
# .\Tokyo\09-01-tokyo.txt already exist in Tokyo folder
# .\Tokyo\09-02-tokyo.txt already exist in Tokyo folder
# .\Tokyo\09-04-tokyo.txt already exist in Tokyo folder
# .\Tokyo\09-05-tokyo.txt already exist in Tokyo folder
# .\Tokyo\09-06-tokyo.txt already exist in Tokyo folder
# .\Tokyo\09-07-tokyo.txt already exist in Tokyo folder
# .\Tokyo\09-10-tokyo.txt already exist in Tokyo folder
# .\Tokyo\09-11-tokyo.txt already exist in Tokyo folder
# .\Tokyo\09-13-tokyo.txt already exist in Tokyo folder
# .\Tokyo\09-14-tokyo.txt already exist in Tokyo folder
# .\Tokyo\09-16-tokyo.txt already exist in Tokyo folder
# .\Tokyo\09-17-tokyo.txt already exist in Tokyo folder
# .\Tokyo\09-19-tokyo.txt already exist in Tokyo folder
# .\Tokyo\09-20-tokyo.txt already exist in Tokyo folder
# .\Tokyo\09-21-tokyo.txt already exist in Tokyo folder
# .\Tokyo\09-22-tokyo.txt already exist in Tokyo folder
# .\Tokyo\09-26-tokyo.txt already exist in Tokyo folder
# .\Tokyo\10-01-tokyo.txt already exist in Tokyo folder
# .\Tokyo\10-05-tokyo.txt already exist in Tokyo folder
# .\Tokyo\10-06-tokyo.txt already exist in Tokyo folder
# .\Tokyo\10-08-tokyo.txt already exist in Tokyo folder
# .\Tokyo\10-13-tokyo.txt already exist in Tokyo folder
# .\Tokyo\10-14-tokyo.txt already exist in Tokyo folder
# .\Tokyo\10-17-tokyo.txt already exist in Tokyo folder
# .\Tokyo\10-19-tokyo.txt already exist in Tokyo folder
# .\Tokyo\10-20-tokyo.txt already exist in Tokyo folder
# .\Tokyo\10-24-tokyo.txt already exist in Tokyo folder
# .\Tokyo\10-25-tokyo.txt already exist in Tokyo folder
# .\Tokyo\10-26-tokyo.txt already exist in Tokyo folder
# .\Tokyo\11-01-tokyo.txt already exist in Tokyo folder
# .\Tokyo\11-02-tokyo.txt already exist in Tokyo folder
# .\Tokyo\11-03-tokyo.txt already exist in Tokyo folder
# .\Tokyo\11-04-tokyo.txt already exist in Tokyo folder
# .\Tokyo\11-05-tokyo.txt already exist in Tokyo folder
# .\Tokyo\11-08-tokyo.txt already exist in Tokyo folder
# .\Tokyo\11-09-tokyo.txt already exist in Tokyo folder
# .\Tokyo\11-12-tokyo.txt already exist in Tokyo folder
# .\Tokyo\11-13-tokyo.txt already exist in Tokyo folder
# .\Tokyo\11-15-tokyo.txt already exist in Tokyo folder
# .\Tokyo\11-17-tokyo.txt already exist in Tokyo folder
# .\Tokyo\11-18-tokyo.txt already exist in Tokyo folder
# .\Tokyo\11-22-tokyo.txt already exist in Tokyo folder
# .\Tokyo\11-23-tokyo.txt already exist in Tokyo folder
# .\Tokyo\11-24-tokyo.txt already exist in Tokyo folder
# .\Tokyo\11-25-tokyo.txt already exist in Tokyo folder
# .\Tokyo\11-28-tokyo.txt already exist in Tokyo folder
# .\Tokyo\12-05-tokyo.txt already exist in Tokyo folder
# .\Tokyo\12-06-tokyo.txt already exist in Tokyo folder
# .\Tokyo\12-09-tokyo.txt already exist in Tokyo folder
# .\Tokyo\12-10-tokyo.txt already exist in Tokyo folder
# .\Tokyo\12-19-tokyo.txt already exist in Tokyo folder
# .\Tokyo\12-20-tokyo.txt already exist in Tokyo folder
# .\Tokyo\12-25-tokyo.txt already exist in Tokyo folder
# .\Tokyo\apr-03_tokyo.jpg already exist in Tokyo folder
# .\Tokyo\apr-07_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\apr-10_tokyo.jpg already exist in Tokyo folder
# .\Tokyo\apr-10_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\apr-11_tokyo.jpg already exist in Tokyo folder
# .\Tokyo\apr-12_tokyo.png already exist in Tokyo folder
# .\Tokyo\apr-15_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\apr-17_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\apr-18_tokyo.png already exist in Tokyo folder
# .\Tokyo\apr-20_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\apr-20_tokyo.png already exist in Tokyo folder
# .\Tokyo\apr-21_tokyo.png already exist in Tokyo folder
# .\Tokyo\apr-23_tokyo.jpg already exist in Tokyo folder
# .\Tokyo\apr-23_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\apr-24_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\apr-27_tokyo.png already exist in Tokyo folder
# .\Tokyo\apr-28_tokyo.png already exist in Tokyo folder
# .\Tokyo\apr-29_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\aug-05_tokyo.jpg already exist in Tokyo folder
# .\Tokyo\aug-12_tokyo.jpg already exist in Tokyo folder
# .\Tokyo\aug-12_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\aug-14_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\aug-20_tokyo.jpg already exist in Tokyo folder
# .\Tokyo\aug-20_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\dec-05_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\dec-06_tokyo.png already exist in Tokyo folder
# .\Tokyo\dec-09_tokyo.png already exist in Tokyo folder
# .\Tokyo\dec-10_tokyo.jpg already exist in Tokyo folder
# .\Tokyo\dec-19_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\dec-20_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\dec-25_tokyo.png already exist in Tokyo folder
# .\Tokyo\feb-03_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\feb-04_tokyo.jpg already exist in Tokyo folder
# .\Tokyo\feb-05_tokyo.png already exist in Tokyo folder
# .\Tokyo\feb-06_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\feb-06_tokyo.png already exist in Tokyo folder
# .\Tokyo\feb-07_tokyo.png already exist in Tokyo folder
# .\Tokyo\feb-09_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\feb-12_tokyo.jpg already exist in Tokyo folder
# .\Tokyo\feb-13_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\feb-14_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\feb-16_tokyo.jpg already exist in Tokyo folder
# .\Tokyo\feb-19_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\feb-20_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\feb-21_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\feb-21_tokyo.png already exist in Tokyo folder
# .\Tokyo\feb-22_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\feb-22_tokyo.png already exist in Tokyo folder
# .\Tokyo\feb-24_tokyo.jpg already exist in Tokyo folder
# .\Tokyo\feb-27_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\jan-08_tokyo.jpg already exist in Tokyo folder
# .\Tokyo\jan-12_tokyo.jpg already exist in Tokyo folder
# .\Tokyo\jan-16_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\jan-19_tokyo.jpg already exist in Tokyo folder
# .\Tokyo\jan-20_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\jan-22_tokyo.png already exist in Tokyo folder
# .\Tokyo\jan-24_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\jul-02_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\jul-02_tokyo.png already exist in Tokyo folder
# .\Tokyo\jul-04_tokyo.png already exist in Tokyo folder
# .\Tokyo\jul-05_tokyo.png already exist in Tokyo folder
# .\Tokyo\jul-06_tokyo.png already exist in Tokyo folder
# .\Tokyo\jul-10_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\jul-11_tokyo.png already exist in Tokyo folder
# .\Tokyo\jul-12_tokyo.jpg already exist in Tokyo folder
# .\Tokyo\jul-13_tokyo.jpg already exist in Tokyo folder
# .\Tokyo\jul-13_tokyo.png already exist in Tokyo folder
# .\Tokyo\jul-15_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\jul-19_tokyo.jpg already exist in Tokyo folder
# .\Tokyo\jul-19_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\jul-19_tokyo.png already exist in Tokyo folder
# .\Tokyo\jul-20_tokyo.png already exist in Tokyo folder
# .\Tokyo\jul-26_tokyo.jpg already exist in Tokyo folder
# .\Tokyo\jul-27_tokyo.jpg already exist in Tokyo folder
# .\Tokyo\jul-27_tokyo.png already exist in Tokyo folder
# .\Tokyo\jul-28_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\jul-29_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\jun-05_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\jun-07_tokyo.png already exist in Tokyo folder
# .\Tokyo\jun-08_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\jun-11_tokyo.jpg already exist in Tokyo folder
# .\Tokyo\jun-12_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\jun-14_tokyo.jpg already exist in Tokyo folder
# .\Tokyo\jun-14_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\jun-17_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\jun-18_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\jun-20_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\jun-22_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\jun-23_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\jun-23_tokyo.png already exist in Tokyo folder
# .\Tokyo\jun-25_tokyo.jpg already exist in Tokyo folder
# .\Tokyo\jun-28_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\jun-29_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\mar-04_tokyo.jpg already exist in Tokyo folder
# .\Tokyo\mar-05_tokyo.jpg already exist in Tokyo folder
# .\Tokyo\mar-05_tokyo.png already exist in Tokyo folder
# .\Tokyo\mar-09_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\mar-09_tokyo.png already exist in Tokyo folder
# .\Tokyo\mar-14_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\mar-15_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\mar-16_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\mar-16_tokyo.png already exist in Tokyo folder
# .\Tokyo\mar-18_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\mar-26_tokyo.png already exist in Tokyo folder
# .\Tokyo\mar-27_tokyo.jpg already exist in Tokyo folder
# .\Tokyo\mar-27_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\may-01_tokyo.jpg already exist in Tokyo folder
# .\Tokyo\may-02_tokyo.jpg already exist in Tokyo folder
# .\Tokyo\may-03_tokyo.jpg already exist in Tokyo folder
# .\Tokyo\may-05_tokyo.jpg already exist in Tokyo folder
# .\Tokyo\may-05_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\may-08_tokyo.png already exist in Tokyo folder
# .\Tokyo\may-15_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\may-16_tokyo.png already exist in Tokyo folder
# .\Tokyo\may-17_tokyo.jpg already exist in Tokyo folder
# .\Tokyo\may-23_tokyo.jpg already exist in Tokyo folder
# .\Tokyo\may-28_tokyo.png already exist in Tokyo folder
# .\Tokyo\may-30_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\nov-01_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\nov-01_tokyo.png already exist in Tokyo folder
# .\Tokyo\nov-02_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\nov-03_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\nov-03_tokyo.png already exist in Tokyo folder
# .\Tokyo\nov-04_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\nov-05_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\nov-08_tokyo.png already exist in Tokyo folder
# .\Tokyo\nov-09_tokyo.png already exist in Tokyo folder
# .\Tokyo\nov-12_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\nov-13_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\nov-15_tokyo.jpg already exist in Tokyo folder
# .\Tokyo\nov-15_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\nov-17_tokyo.png already exist in Tokyo folder
# .\Tokyo\nov-18_tokyo.jpg already exist in Tokyo folder
# .\Tokyo\nov-22_tokyo.jpg already exist in Tokyo folder
# .\Tokyo\nov-23_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\nov-24_tokyo.jpg already exist in Tokyo folder
# .\Tokyo\nov-24_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\nov-25_tokyo.jpg already exist in Tokyo folder
# .\Tokyo\nov-28_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\oct-01_tokyo.jpg already exist in Tokyo folder
# .\Tokyo\oct-05_tokyo.jpg already exist in Tokyo folder
# .\Tokyo\oct-06_tokyo.jpg already exist in Tokyo folder
# .\Tokyo\oct-08_tokyo.png already exist in Tokyo folder
# .\Tokyo\oct-13_tokyo.jpg already exist in Tokyo folder
# .\Tokyo\oct-14_tokyo.png already exist in Tokyo folder
# .\Tokyo\oct-17_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\oct-19_tokyo.png already exist in Tokyo folder
# .\Tokyo\oct-20_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\oct-24_tokyo.jpg already exist in Tokyo folder
# .\Tokyo\oct-25_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\oct-26_tokyo.jpg already exist in Tokyo folder
# .\Tokyo\sep-01_tokyo.png already exist in Tokyo folder
# .\Tokyo\sep-02_tokyo.png already exist in Tokyo folder
# .\Tokyo\sep-04_tokyo.jpg already exist in Tokyo folder
# .\Tokyo\sep-05_tokyo.png already exist in Tokyo folder
# .\Tokyo\sep-06_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\sep-07_tokyo.jpg already exist in Tokyo folder
# .\Tokyo\sep-07_tokyo.png already exist in Tokyo folder
# .\Tokyo\sep-10_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\sep-11_tokyo.jpg already exist in Tokyo folder
# .\Tokyo\sep-11_tokyo.png already exist in Tokyo folder
# .\Tokyo\sep-13_tokyo.png already exist in Tokyo folder
# .\Tokyo\sep-14_tokyo.jpg already exist in Tokyo folder
# .\Tokyo\sep-16_tokyo.jpg already exist in Tokyo folder
# .\Tokyo\sep-17_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\sep-19_tokyo.jpg already exist in Tokyo folder
# .\Tokyo\sep-20_tokyo.png already exist in Tokyo folder
# .\Tokyo\sep-21_tokyo.jpg already exist in Tokyo folder
# .\Tokyo\sep-21_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\sep-22_tokyo.jpg already exist in Tokyo folder
# .\Tokyo\sep-22_tokyo.pdf already exist in Tokyo folder
# .\Tokyo\sep-22_tokyo.png already exist in Tokyo folder
# .\Tokyo\sep-26_tokyo.jpg already exist in Tokyo folder
